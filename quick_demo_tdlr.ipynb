# %% [markdown]
# <a href="https://colab.research.google.com/github/yzhou359/MakeItTalk/blob/main/quick_demo_tdlr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MakeItTalk Quick Demo (natural human face animation)
#
# ## TDLR version
#
# Remember to change to GPU runtime first!

# %%
# !conda install pytorch torchvision torchaudio -c pytorch-nightly -y
# Out:
# Channels:
#  - pytorch-nightly
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/gaspari/MakeItTalk/.conda
#
#   added / updated specs:
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pytorch-2.3.0.dev20231222  |          py3.8_0        52.6 MB  pytorch-nightly
#     torchaudio-2.2.0.dev20231222|         py38_cpu         4.8 MB  pytorch-nightly
#     torchvision-0.18.0.dev20231222|         py38_cpu         6.7 MB  pytorch-nightly
#     ------------------------------------------------------------
#                                            Total:        64.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   brotli-python      pkgs/main/osx-arm64::brotli-python-1.0.9-py38hc377ac9_7
#   certifi            pkgs/main/osx-arm64::certifi-2023.11.17-py38hca03da5_0
#   cffi               pkgs/main/osx-arm64::cffi-1.16.0-py38h80987f9_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   cryptography       pkgs/main/osx-arm64::cryptography-41.0.7-py38hd4332d6_0
#   filelock           pkgs/main/osx-arm64::filelock-3.13.1-py38hca03da5_0
#   freetype           pkgs/main/osx-arm64::freetype-2.12.1-h1192e45_0
#   giflib             pkgs/main/osx-arm64::giflib-5.2.1-h80987f9_3
#   gmp                pkgs/main/osx-arm64::gmp-6.2.1-hc377ac9_3
#   gmpy2              pkgs/main/osx-arm64::gmpy2-2.1.2-py38h8c48613_0
#   idna               pkgs/main/osx-arm64::idna-3.4-py38hca03da5_0
#   jinja2             pkgs/main/osx-arm64::jinja2-3.1.2-py38hca03da5_0
#   jpeg               pkgs/main/osx-arm64::jpeg-9e-h80987f9_1
#   lcms2              pkgs/main/osx-arm64::lcms2-2.12-hba8e193_0
#   lerc               pkgs/main/osx-arm64::lerc-3.0-hc377ac9_0
#   libdeflate         pkgs/main/osx-arm64::libdeflate-1.17-h80987f9_1
#   libgfortran        pkgs/main/osx-arm64::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-11.3.0-h009349e_28
#   libjpeg-turbo      pkgs/main/osx-arm64::libjpeg-turbo-2.0.0-h1a28f6b_0
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.21-h269037a_0
#   libpng             pkgs/main/osx-arm64::libpng-1.6.39-h80987f9_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.5.1-h313beb8_0
#   libwebp            pkgs/main/osx-arm64::libwebp-1.3.2-ha3663a8_0
#   libwebp-base       pkgs/main/osx-arm64::libwebp-base-1.3.2-h80987f9_0
#   llvm-openmp        pkgs/main/osx-arm64::llvm-openmp-14.0.6-hc6e5704_0
#   lz4-c              pkgs/main/osx-arm64::lz4-c-1.9.4-h313beb8_0
#   markupsafe         pkgs/main/osx-arm64::markupsafe-2.1.1-py38h1a28f6b_0
#   mpc                pkgs/main/osx-arm64::mpc-1.1.0-h8c48613_1
#   mpfr               pkgs/main/osx-arm64::mpfr-4.0.2-h695f6f0_1
#   mpmath             pkgs/main/osx-arm64::mpmath-1.3.0-py38hca03da5_0
#   networkx           pkgs/main/osx-arm64::networkx-3.1-py38hca03da5_0
#   numpy              pkgs/main/osx-arm64::numpy-1.24.3-py38h1398885_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.24.3-py38h90707a3_0
#   openjpeg           pkgs/main/osx-arm64::openjpeg-2.3.0-h7a6adac_2
#   pillow             pkgs/main/osx-arm64::pillow-10.0.1-py38h3b245a6_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/osx-arm64::pyopenssl-23.2.0-py38hca03da5_0
#   pysocks            pkgs/main/osx-arm64::pysocks-1.7.1-py38hca03da5_0
#   pytorch            pytorch-nightly/osx-arm64::pytorch-2.3.0.dev20231222-py3.8_0
#   pyyaml             pkgs/main/osx-arm64::pyyaml-6.0.1-py38h80987f9_0
#   requests           pkgs/main/osx-arm64::requests-2.31.0-py38hca03da5_0
#   sympy              pkgs/main/osx-arm64::sympy-1.12-py38hca03da5_0
#   torchaudio         pytorch-nightly/osx-arm64::torchaudio-2.2.0.dev20231222-py38_cpu
#   torchvision        pytorch-nightly/osx-arm64::torchvision-0.18.0.dev20231222-py38_cpu
#   urllib3            pkgs/main/osx-arm64::urllib3-1.26.18-py38hca03da5_0
#   yaml               pkgs/main/osx-arm64::yaml-0.2.5-h1a28f6b_0
#   zstd               pkgs/main/osx-arm64::zstd-1.5.5-hd90d995_0
#
#
#
# Downloading and Extracting Packages:
# torchvision-0.18.0.d | 6.7 MB    |                                       |   0%
# pytorch-2.3.0.dev202 | 52.6 MB   |                                       |   0%
#
# torchaudio-2.2.0.dev | 4.8 MB    |                                       |   0%
#
# torchaudio-2.2.0.dev | 4.8 MB    | ##################################### | 100%
#
# torchvision-0.18.0.d | 6.7 MB    | ##################################### | 100%
# pytorch-2.3.0.dev202 | 52.6 MB   | ##################################### | 100%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Preparation (run only once)

# %%
print('Git clone project and install requirements...')
# !pip install -r requirements.txt
# !pip install tensorboardX
# !mkdir examples/dump
# !mkdir examples/ckpt
# !pip install gdown
# Out:
# Git clone project and install requirements...
# Requirement already satisfied: ffmpeg-python in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: opencv-python in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (4.8.1.78)
# Requirement already satisfied: face_alignment in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: scikit-learn in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: pydub in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (0.25.1)
# Requirement already satisfied: pynormalize in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: soundfile in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: librosa in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (0.10.1)
# Requirement already satisfied: pysptk in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: pyworld in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.3.4)
# Requirement already satisfied: resemblyzer in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: future in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ffmpeg-python->-r requirements.txt (line 1)) (0.18.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from opencv-python->-r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: torch in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from face_alignment->-r requirements.txt (line 3)) (2.3.0.dev20231222)
# Requirement already satisfied: scipy>=0.17 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from face_alignment->-r requirements.txt (line 3)) (1.10.1)
# Requirement already satisfied: scikit-image in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from face_alignment->-r requirements.txt (line 3)) (0.21.0)
# Requirement already satisfied: tqdm in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from face_alignment->-r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: numba in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from face_alignment->-r requirements.txt (line 3)) (0.58.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: mutagen>=1.40.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from pynormalize->-r requirements.txt (line 6)) (1.47.0)
# Requirement already satisfied: cffi>=1.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from soundfile->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from librosa->-r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from librosa->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from librosa->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from librosa->-r requirements.txt (line 8)) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from librosa->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from librosa->-r requirements.txt (line 8)) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from librosa->-r requirements.txt (line 8)) (1.0.7)
# Requirement already satisfied: cython>=0.28.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from pysptk->-r requirements.txt (line 9)) (3.0.7)
# Requirement already satisfied: webrtcvad>=2.0.10 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from resemblyzer->-r requirements.txt (line 11)) (2.0.10)
# Requirement already satisfied: typing in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from resemblyzer->-r requirements.txt (line 11)) (3.7.4.3)
# Requirement already satisfied: pycparser in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 7)) (2.21)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from numba->face_alignment->-r requirements.txt (line 3)) (0.41.1)
# Requirement already satisfied: importlib-metadata in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from numba->face_alignment->-r requirements.txt (line 3)) (7.0.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.31.0)
# Requirement already satisfied: filelock in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.13.1)
# Requirement already satisfied: sympy in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.1)
# Requirement already satisfied: jinja2 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: fsspec in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (2023.12.2)
# Requirement already satisfied: pillow>=9.0.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (10.0.1)
# Requirement already satisfied: imageio>=2.27 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2023.11.17)
# Requirement already satisfied: zipp>=0.5 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from importlib-metadata->numba->face_alignment->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from jinja2->torch->face_alignment->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from sympy->torch->face_alignment->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: tensorboardX in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from tensorboardX) (1.24.3)
# Requirement already satisfied: packaging in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from tensorboardX) (23.2)
# Requirement already satisfied: protobuf>=3.20 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from tensorboardX) (4.25.1)
# mkdir: examples/dump: File exists
# mkdir: examples/ckpt: File exists
# Requirement already satisfied: gdown in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (4.7.1)
# Requirement already satisfied: filelock in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown -O examples/ckpt/ckpt_autovc.pth https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x
# !gdown -O examples/ckpt/ckpt_content_branch.pth https://drive.google.com/uc?id=1r3bfEvTVl6pCNw5xwUhEglwDHjWtAqQp
# !gdown -O examples/ckpt/ckpt_speaker_branch.pth https://drive.google.com/uc?id=1rV0jkyDqPW-aDJcj7xSO6Zt1zSXqn1mu
# !gdown -O examples/ckpt/ckpt_116_i2i_comb.pth https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a
# !gdown -O examples/dump/emb.pickle https://drive.google.com/uc?id=18-0CYl5E6ungS3H4rRSHjfYvvm-WwjTI
print('Done!')
# Out:
# Traceback (most recent call last):
#   File "/Users/gaspari/MakeItTalk/.conda/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/cli.py", line 156, in main
#     filename = download(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/download.py", line 225, in download
#     with open(cookies_file, "w") as f:
# PermissionError: [Errno 13] Permission denied: '/Users/gaspari/.cache/gdown/cookies.json'
# ^C
# Traceback (most recent call last):
#   File "/Users/gaspari/MakeItTalk/.conda/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/cli.py", line 156, in main
#     filename = download(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/download.py", line 161, in download
#     res = sess.get(url, stream=True, verify=verify)
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/requests/sessions.py", line 725, in send
#     history = [resp for resp in gen]
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/requests/sessions.py", line 725, in <listcomp>
#     history = [resp for resp in gen]
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/requests/sessions.py", line 266, in resolve_redirects
#     resp = self.send(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py", line 715, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py", line 467, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py", line 462, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/http/client.py", line 1348, in getresponse
#     response.begin()
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/http/client.py", line 316, in begin
#     version, status, reason = self._read_status()
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/http/client.py", line 277, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/ssl.py", line 1132, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/gaspari/MakeItTalk/.conda/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/cli.py", line 156, in main
#     filename = download(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/download.py", line 225, in download
#     with open(cookies_file, "w") as f:
# PermissionError: [Errno 13] Permission denied: '/Users/gaspari/.cache/gdown/cookies.json'
# Traceback (most recent call last):
#   File "/Users/gaspari/MakeItTalk/.conda/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/cli.py", line 156, in main
#     filename = download(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/download.py", line 225, in download
#     with open(cookies_file, "w") as f:
# PermissionError: [Errno 13] Permission denied: '/Users/gaspari/.cache/gdown/cookies.json'
# Traceback (most recent call last):
#   File "/Users/gaspari/MakeItTalk/.conda/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/cli.py", line 156, in main
#     filename = download(
#   File "/Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages/gdown/download.py", line 225, in download
#     with open(cookies_file, "w") as f:
# PermissionError: [Errno 13] Permission denied: '/Users/gaspari/.cache/gdown/cookies.json'
# Done!

# %% [markdown]
# ## Animate your photos here!
#
# - Upload your images to `examples` with size `256x256`. Or use existing ones.
#
# - Upload your speech audio files (could be many) to `examples`. Since it will process all `.wav` files under `examples`, remember to delete non-necessary `.wav` files. Or use an existing one `M6_04_16k.wav`.

# %% [markdown]
# ## Step 1/3: Choose your image (in below Dropdown).

# %%
# !pip install ipywidgets
# !pip install matplotlib
# Out:
# Requirement already satisfied: ipywidgets in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipywidgets) (8.12.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipywidgets) (5.14.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: typing-extensions in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: appnope in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Collecting matplotlib
#   Using cached matplotlib-3.7.4-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.47.0-cp38-cp38-macosx_10_9_universal2.whl.metadata (157 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.20 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from matplotlib) (10.0.1)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/gaspari/MakeItTalk/.conda/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.7.4-cp38-cp38-macosx_11_0_arm64.whl (7.3 MB)
# Using cached contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.47.0-cp38-cp38-macosx_10_9_universal2.whl (2.8 MB)
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Using cached kiwisolver-1.4.5-cp38-cp38-macosx_11_0_arm64.whl (66 kB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.47.0 importlib-resources-6.1.1 kiwisolver-1.4.5 matplotlib-3.7.4 pyparsing-3.1.1

# %%
import ipywidgets as widgets
import glob
import matplotlib.pyplot as plt
print("Choose the image name to animate: (saved in folder 'examples/')")
img_list = glob.glob1('examples', '*.jpg')
img_list.sort()
img_list = [item.split('.')[0] for item in img_list]
default_head_name = widgets.Dropdown(options=img_list, value='paint_boy')
def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        plt.imshow(plt.imread('examples/{}.jpg'.format(default_head_name.value)))
        plt.axis('off')
        plt.show()
default_head_name.observe(on_change)
display(default_head_name)
plt.imshow(plt.imread('examples/{}.jpg'.format(default_head_name.value)))
plt.axis('off')
plt.show()
# Out:
# Choose the image name to animate: (saved in folder 'examples/')
# Dropdown(index=41, options=('angelina', 'anne', 'anne2', 'audrey', 'aya', 'captain', 'captain2', 'cesi', 'chri…

# %% [markdown]
# ## Step 2/3: Setup your animation controllers (on right Sliders).

# %%
#@markdown # Animation Controllers
#@markdown Amplify the lip motion in horizontal direction
AMP_LIP_SHAPE_X = 2 #@param {type:"slider", min:0.5, max:5.0, step:0.1}

#@markdown Amplify the lip motion in vertical direction
AMP_LIP_SHAPE_Y = 2 #@param {type:"slider", min:0.5, max:5.0, step:0.1}

#@markdown Amplify the head pose motion (usually smaller than 1.0, put it to 0. for a static head pose)
AMP_HEAD_POSE_MOTION = 0.35 #@param {type:"slider", min:0.0, max:1.0, step:0.05}

#@markdown Add naive eye blink
ADD_NAIVE_EYE = True  #@param ["False", "True"] {type:"raw"}

#@markdown If your image has an opened mouth, put this as True, else False
CLOSE_INPUT_FACE_MOUTH = False  #@param ["False", "True"] {type:"raw"}          


#@markdown # Landmark Adjustment

#@markdown Adjust upper lip thickness (postive value means thicker)
UPPER_LIP_ADJUST = -1 #@param {type:"slider", min:-3.0, max:3.0, step:1.0}

#@markdown Adjust lower lip thickness (postive value means thicker)
LOWER_LIP_ADJUST = -1 #@param {type:"slider", min:-3.0, max:3.0, step:1.0}

#@markdown Adjust static lip width (in multipication)
LIP_WIDTH_ADJUST = 1.0 #@param {type:"slider", min:0.8, max:1.2, step:0.01}

# %% [markdown]
# ## Step 3/3: One-click to Run (just wait in seconds).

# %%
import sys
sys.path.append("thirdparty/AdaptiveWingLoss")
import os, glob
import numpy as np
import cv2
import argparse
from src.approaches.train_image_translation import Image_translation_block
import torch
import pickle
import face_alignment
from src.autovc.AutoVC_mel_Convertor_retrain_version import AutoVC_mel_Convertor
import shutil
import time
import util.utils as util
from scipy.signal import savgol_filter
from src.approaches.train_audio2landmark import Audio2landmark_model

sys.stdout = open(os.devnull, 'a')

parser = argparse.ArgumentParser()
parser.add_argument('--jpg', type=str, default='{}.jpg'.format(default_head_name.value))
parser.add_argument('--close_input_face_mouth', default=CLOSE_INPUT_FACE_MOUTH, action='store_true')
parser.add_argument('--load_AUTOVC_name', type=str, default='examples/ckpt/ckpt_autovc.pth')
parser.add_argument('--load_a2l_G_name', type=str, default='examples/ckpt/ckpt_speaker_branch.pth')
parser.add_argument('--load_a2l_C_name', type=str, default='examples/ckpt/ckpt_content_branch.pth') #ckpt_audio2landmark_c.pth')
parser.add_argument('--load_G_name', type=str, default='examples/ckpt/ckpt_116_i2i_comb.pth') #ckpt_image2image.pth') #ckpt_i2i_finetune_150.pth') #c
parser.add_argument('--amp_lip_x', type=float, default=AMP_LIP_SHAPE_X)
parser.add_argument('--amp_lip_y', type=float, default=AMP_LIP_SHAPE_Y)
parser.add_argument('--amp_pos', type=float, default=AMP_HEAD_POSE_MOTION)
parser.add_argument('--reuse_train_emb_list', type=str, nargs='+', default=[]) #  ['iWeklsXc0H8']) #['45hn7-LXDX8']) #['E_kmpT-EfOg']) #'iWeklsXc0H8', '29k8RtSUjE0', '45hn7-LXDX8',
parser.add_argument('--add_audio_in', default=False, action='store_true')
parser.add_argument('--comb_fan_awing', default=False, action='store_true')
parser.add_argument('--output_folder', type=str, default='examples')
parser.add_argument('--test_end2end', default=True, action='store_true')
parser.add_argument('--dump_dir', type=str, default='', help='')
parser.add_argument('--pos_dim', default=7, type=int)
parser.add_argument('--use_prior_net', default=True, action='store_true')
parser.add_argument('--transformer_d_model', default=32, type=int)
parser.add_argument('--transformer_N', default=2, type=int)
parser.add_argument('--transformer_heads', default=2, type=int)
parser.add_argument('--spk_emb_enc_size', default=16, type=int)
parser.add_argument('--init_content_encoder', type=str, default='')
parser.add_argument('--lr', type=float, default=1e-3, help='learning rate')
parser.add_argument('--reg_lr', type=float, default=1e-6, help='weight decay')
parser.add_argument('--write', default=False, action='store_true')
parser.add_argument('--segment_batch_size', type=int, default=1, help='batch size')
parser.add_argument('--emb_coef', default=3.0, type=float)
parser.add_argument('--lambda_laplacian_smooth_loss', default=1.0, type=float)
parser.add_argument('--use_11spk_only', default=False, action='store_true')
parser.add_argument('-f')
opt_parser = parser.parse_args()

img = cv2.imread('examples/' + opt_parser.jpg)
predictor = face_alignment.FaceAlignment(face_alignment.LandmarksType._3D, device='cpu', flip_input=True)
shapes = predictor.get_landmarks(img)
if (not shapes or len(shapes) != 1):
    print('Cannot detect face landmarks. Exit.')
    exit(-1)
shape_3d = shapes[0]
if(opt_parser.close_input_face_mouth):
    util.close_input_face_mouth(shape_3d)
shape_3d[48:, 0] = (shape_3d[48:, 0] - np.mean(shape_3d[48:, 0])) * LIP_WIDTH_ADJUST + np.mean(shape_3d[48:, 0]) # wider lips
shape_3d[49:54, 1] -= UPPER_LIP_ADJUST           # thinner upper lip
shape_3d[55:60, 1] += LOWER_LIP_ADJUST           # thinner lower lip
shape_3d[[37,38,43,44], 1] -=2.    # larger eyes
shape_3d[[40,41,46,47], 1] +=2.    # larger eyes
shape_3d, scale, shift = util.norm_input_face(shape_3d)

print("Loaded Image...", file=sys.stderr)

au_data = []
au_emb = []
ains = glob.glob1('examples', '*.wav')
ains = [item for item in ains if item is not 'tmp.wav']
ains.sort()
for ain in ains:
    os.system('/opt/homebrew/bin/ffmpeg -y -loglevel error -i examples/{} -ar 16000 examples/tmp.wav'.format(ain))
    shutil.copyfile('examples/tmp.wav', 'examples/{}'.format(ain))

    # au embedding
    from thirdparty.resemblyer_util.speaker_emb import get_spk_emb
    me, ae = get_spk_emb('examples/{}'.format(ain))
    au_emb.append(me.reshape(-1))

    print('Processing audio file', ain)
    c = AutoVC_mel_Convertor('examples')

    au_data_i = c.convert_single_wav_to_autovc_input(audio_filename=os.path.join('examples', ain),
           autovc_model_path=opt_parser.load_AUTOVC_name)
    au_data += au_data_i
if(os.path.isfile('examples/tmp.wav')):
    os.remove('examples/tmp.wav')

print("Loaded audio...", file=sys.stderr)

# landmark fake placeholder
fl_data = []
rot_tran, rot_quat, anchor_t_shape = [], [], []
for au, info in au_data:
    au_length = au.shape[0]
    fl = np.zeros(shape=(au_length, 68 * 3))
    fl_data.append((fl, info))
    rot_tran.append(np.zeros(shape=(au_length, 3, 4)))
    rot_quat.append(np.zeros(shape=(au_length, 4)))
    anchor_t_shape.append(np.zeros(shape=(au_length, 68 * 3)))

if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_au.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_au.pickle'))
if (os.path.exists(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))

with open(os.path.join('examples', 'dump', 'random_val_fl.pickle'), 'wb') as fp:
    pickle.dump(fl_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_au.pickle'), 'wb') as fp:
    pickle.dump(au_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_gaze.pickle'), 'wb') as fp:
    gaze = {'rot_trans':rot_tran, 'rot_quat':rot_quat, 'anchor_t_shape':anchor_t_shape}
    pickle.dump(gaze, fp)

model = Audio2landmark_model(opt_parser, jpg_shape=shape_3d)
if(len(opt_parser.reuse_train_emb_list) == 0):
    model.test(au_emb=au_emb)
else:
    model.test(au_emb=None)

print("Audio->Landmark...", file=sys.stderr)

fls = glob.glob1('examples', 'pred_fls_*.txt')
fls.sort()

for i in range(0,len(fls)):
    fl = np.loadtxt(os.path.join('examples', fls[i])).reshape((-1, 68,3))
    fl[:, :, 0:2] = -fl[:, :, 0:2]
    fl[:, :, 0:2] = fl[:, :, 0:2] / scale - shift

    if (ADD_NAIVE_EYE):
        fl = util.add_naive_eye(fl)

    # additional smooth
    fl = fl.reshape((-1, 204))
    fl[:, :48 * 3] = savgol_filter(fl[:, :48 * 3], 15, 3, axis=0)
    fl[:, 48*3:] = savgol_filter(fl[:, 48*3:], 5, 3, axis=0)
    fl = fl.reshape((-1, 68, 3))

    ''' STEP 6: Imag2image translation '''
    model = Image_translation_block(opt_parser, single_test=True)
    with torch.no_grad():
        model.single_test(jpg=img, fls=fl, filename=fls[i], prefix=opt_parser.jpg.split('.')[0])
        print('finish image2image gen')
    os.remove(os.path.join('examples', fls[i]))

    print("{} / {}: Landmark->Face...".format(i+1, len(fls)), file=sys.stderr)
print("Done!", file=sys.stderr)
# Out:
# <>:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# usage: ipykernel_launcher.py [-h] [--jpg JPG] [--close_input_face_mouth]
#                              [--load_AUTOVC_name LOAD_AUTOVC_NAME]
#                              [--load_a2l_G_name LOAD_A2L_G_NAME]
#                              [--load_a2l_C_name LOAD_A2L_C_NAME]
#                              [--load_G_name LOAD_G_NAME]
#                              [--amp_lip_x AMP_LIP_X] [--amp_lip_y AMP_LIP_Y]
#                              [--amp_pos AMP_POS]
#                              [--reuse_train_emb_list REUSE_TRAIN_EMB_LIST [REUSE_TRAIN_EMB_LIST ...]]
#                              [--add_audio_in] [--comb_fan_awing]
#                              [--output_folder OUTPUT_FOLDER] [--test_end2end]
#                              [--dump_dir DUMP_DIR] [--pos_dim POS_DIM]
#                              [--use_prior_net]
#                              [--transformer_d_model TRANSFORMER_D_MODEL]
#                              [--transformer_N TRANSFORMER_N]
#                              [--transformer_heads TRANSFORMER_HEADS]
#                              [--spk_emb_enc_size SPK_EMB_ENC_SIZE]
#                              [--init_content_encoder INIT_CONTENT_ENCODER]
#                              [--lr LR] [--reg_lr REG_LR] [--write]
#                              [--segment_batch_size SEGMENT_BATCH_SIZE]
#                              [--emb_coef EMB_COEF]
#                              [--lambda_laplacian_smooth_loss LAMBDA_LAPLACIAN_SMOOTH_LOSS]
#                              [--use_11spk_only] [-f F]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/gaspari/Library/Jupyter/runtime/kernel-v2-13306mgMKEwEJTq4m.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %% [markdown]
# ## Visualize your animation!

# %%
from IPython.display import HTML
from base64 import b64encode

for ain in ains:
  OUTPUT_MP4_NAME = '{}_pred_fls_{}_audio_embed.mp4'.format(
    opt_parser.jpg.split('.')[0],
    ain.split('.')[0]
    )
  mp4 = open('examples/{}'.format(OUTPUT_MP4_NAME),'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

  print('Display animation: examples/{}'.format(OUTPUT_MP4_NAME), file=sys.stderr)
  display(HTML("""
  <video width=600 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
# Out:
# Display animation: examples/dragonmom_pred_fls_M6_04_16k_audio_embed.mp4
#   <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>
